# %% [markdown]
# ## Train Custom Word2Vec Model on Product Descriptions

# %% [markdown]
# Word vectors trained to represent the use in product description domain - results are averaged to represent item as average of word vectors in product description

# %%
import pandas as pd
import numpy as np

# %%
import gensim
from gensim.models import FastText
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
data_all = pd.read_pickle("data/processed_data/articles_info.pkl")

# %%
data_all.dtypes
# Out:
# anbieter_artikelnummer                 object
# anbieterID                            float64
# erstanlageDatum           datetime64[ns, UTC]
# stueck_pro_ve                         float64
# artikelID                             float64
# anbietermarktplatz                     object
# warengruppe                            object
# groupID_1                             float64
# groupID_2                             float64
# preis_euro                            float64
# text_clean                             object
# dtype: object

# %%
data = data_all.text_clean.tolist()
len(data)
# Out:
# 750206

# %% [markdown]
# Create Stopwords to delete from descriptions

# %%
my_stop_words = STOPWORDS.union(set(['size', 'color', 'material', 'product', 'dimension', 'length', 'package', 'brand', 
                     'pack', 'width', 'piece', 'height', 'quality', 'group', 'high', 'model', 'article', 'assort',
                     'price', 'weight', 'colour', 'products', 'type', 'design', 'diameter'])) 
# retrieved from previous project

# %%
my_stop_words
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'article',
#            'as',
#            'assort',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'brand',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'color',
#            'colour',
#            'computer',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'design',
#            'detail',
#            'diameter',
#            'did',
#            'didn',
#            'dimension',
#            'do',
#            'does',
#            'doesn',
#            'doing',
#            'don',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'group',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'height',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'high',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'just',
#            'keep',
#            'kg',
#            'km',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'length',
#            'less',
#            'ltd',
#            'made',
#            'make',
#            'many',
#            'material',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'model',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'pack',
#            'package',
#            'part',
#            'per',
#            'perhaps',
#            'piece',
#            'please',
#            'price',
#            'product',
#            'products',
#            'put',
#            'quality',
#            'quite',
#            'rather',
#            're',
#            'really',
#            'regarding',
#            'same',
#            'say',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'size',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'type',
#            'un',
#            'under',
#            'unless',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'used',
#            'using',
#            'various',
#            'very',
#            'via',
#            'was',
#            'we',
#            'weight',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'width',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %% [markdown]
# Define and test process:
# - remove stopwords
# - remove words less than 4 characters
# - lemmatize words

# %%
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in my_stop_words and len(token) > 3: # standard stopwords and remove shorter 3 
            result.append(WordNetLemmatizer().lemmatize(token, pos='v'))
    return result

# %%
preprocess(data[500])
# Out:
# ['serum',
#  'model',
#  'body',
#  'firm',
#  'verona',
#  'olive',
#  'serum',
#  'model',
#  'body',
#  'firm',
#  'promote',
#  'slimming',
#  'body',
#  'model',
#  'contain',
#  'drenaliptm',
#  'have',
#  'anti',
#  'celulitowych']

# %%
#preprocessed_data = data_all['text_clean'].map(preprocess)
preprocessed_data = [preprocess(str(data[i])) for i in range(len(data))]

# %% [markdown]
# Train word2vec model for all words that are in the corpus at least 3 times

# %%
model = Word2Vec(preprocessed_data, size=150, window=5, min_count=3, workers=4) 
model.save("data/models/word2vec/word2vec.model")
# killed on my computer.. try again on Google Cloud

# %%
model.wv.most_similar('christmas')
# Out:
# [('santa', 0.5143343210220337),
#  ('claus', 0.5046408176422119),
#  ('noel', 0.4972369968891144),
#  ('snowman', 0.49606654047966003),
#  ('sledge', 0.47944319248199463),
#  ('xmas', 0.47759997844696045),
#  ('reindeer', 0.47422361373901367),
#  ('icicle', 0.46171554923057556),
#  ('gingerbread', 0.45593175292015076),
#  ('tannenbaum', 0.4540959298610687)]

# %%
model.wv['cup']
# Out:
# array([-2.1599779e+00,  6.8682367e-01, -7.2076142e-01, -4.7736767e-01,
#         1.4280242e+00, -3.6823744e-01,  1.0172700e+00, -8.3808619e-01,
#        -1.8237360e+00,  4.6261322e-02,  2.2415426e+00, -5.5890721e-01,
#         2.5289288e+00,  1.7290318e-01, -4.0860283e-01,  1.7178463e+00,
#        -1.5374784e-01,  9.7109646e-01, -2.5287887e-01, -4.0118721e-01,
#         3.3619389e-02,  2.7784282e-01, -4.7964957e-01, -4.9002728e-01,
#        -4.9541393e-01, -1.1239982e+00,  6.8191260e-01, -7.4850720e-01,
#        -2.8618386e-01, -1.0420500e+00,  7.3444045e-01, -8.5160333e-01,
#         9.9954742e-01,  9.1576286e-02,  1.7469946e+00,  1.3060845e+00,
#         2.4147463e+00, -2.1092894e+00, -5.4620767e-01, -8.5532054e-02,
#         3.7522030e-01,  1.0530726e+00, -2.0046477e+00, -4.4788820e-01,
#        -1.2595268e+00, -4.9259755e-01, -1.3246691e+00,  3.2946162e-02,
#        -3.7333685e-01,  1.9794825e-01, -3.5582104e-01, -1.1775303e+00,
#         2.4583805e+00, -1.4190321e+00, -6.0393763e-01, -2.9245725e+00,
#         5.4942513e-01,  1.6497890e+00,  1.9163846e+00,  7.9864234e-01,
#        -2.2472522e+00, -3.4078193e+00, -3.2421763e+00,  1.5427965e-03,
#        -1.6336564e+00,  1.6099012e+00, -7.3896301e-01, -9.0615720e-01,
#        -9.5680279e-01,  1.2200038e+00, -4.5961985e-01, -2.0849235e-01,
#         2.6111716e-01,  1.5153254e+00,  1.3789254e+00,  1.3704550e-01,
#        -2.2334507e-01,  1.5074785e+00,  1.3268273e-01, -3.7744844e-01,
#         1.3293366e+00, -1.5963705e+00,  1.9751074e+00, -5.6814569e-01,
#        -1.9795243e+00, -1.7858467e-01,  2.1604798e+00,  1.1993476e+00,
#         3.6697870e-01,  7.2705138e-01, -1.4635081e+00, -6.8608230e-01,
#        -8.1349902e-02, -1.6597943e+00,  2.1565020e+00, -1.4526659e+00,
#         1.2272563e+00,  3.0247223e-01,  1.6622162e-01, -9.3838286e-01,
#         4.3255496e-01, -2.1856511e+00,  2.0975552e+00, -8.4389544e-01,
#         2.0932024e+00, -6.7993152e-01, -1.0198915e+00,  1.2408049e+00,
#         1.1593306e+00, -1.1629841e+00,  1.3446820e+00, -1.7198647e+00,
#        -1.2341933e+00, -2.7217619e+00,  1.4690946e+00,  7.2760230e-01,
#        -4.9211842e-01,  1.2679943e-01,  1.6302165e+00, -2.5089505e-01,
#        -1.2367811e+00,  1.8496809e+00, -1.6343995e+00,  2.6290813e-01,
#         3.4046289e-02, -4.3134579e-01,  2.4418348e-01,  1.0708933e+00,
#         2.2366326e-01, -1.9294558e-01,  1.0654440e+00, -1.7800109e+00,
#        -2.6253054e-01, -2.6868871e-01,  8.2452911e-01, -9.3689179e-01,
#        -1.3359930e-01,  3.1408765e+00, -1.8127519e+00,  6.7929506e-02,
#         1.6569403e+00, -1.2881757e+00,  2.2682109e+00, -2.5431974e+00,
#        -3.1930742e-01,  2.4185989e-05, -4.2091087e-01,  2.2620225e+00,
#         1.4592625e+00, -1.8666909e+00], dtype=float32)

# %%
word_vectors = model.wv

# %% [markdown]
# Function to calculate the average vector across all words in the description

# %%
def get_mean_vector(word2vec_model, words):
    # remove out-of-vocabulary words
    words = [word for word in words if word in word_vectors.vocab]
    if len(words) >= 1:
        return np.mean(word2vec_model[words], axis=0)
    else:
        return []

# %%
get_mean_vector(model, preprocessed_data[1])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# array([ 0.19540575, -0.07194629, -0.34633487, -0.24592285, -1.0357192 ,
#        -0.24799103,  0.2567575 ,  0.20529896,  1.3067074 ,  1.9637139 ,
#         0.8820851 , -0.4385833 , -0.03654981, -0.7472502 ,  0.29228267,
#         2.221755  , -0.01760486,  0.01895112,  0.07876571,  0.508968  ,
#         0.64661425,  0.598393  ,  1.0541649 , -1.2646081 ,  0.02103028,
#         0.9427252 , -0.66634536, -2.2871926 ,  0.32233435, -0.9723202 ,
#         0.23202752,  2.888791  , -0.25944984, -1.2893883 , -0.8821279 ,
#        -1.8014927 , -0.6933597 , -0.94349897,  0.97366196,  0.4523265 ,
#        -0.48284388, -1.2377995 , -0.2942778 ,  0.02108408, -0.44196057,
#        -0.90491664,  1.7155467 , -0.98383105,  0.3765968 , -0.09718102,
#        -2.3913531 , -0.19783945, -1.0304915 ,  1.4013278 ,  0.02132689,
#        -0.22636081,  0.5579515 ,  0.17752208, -0.556667  ,  0.02837368,
#        -1.5287467 ,  0.08335496,  0.9742878 ,  0.1800721 ,  0.12457419,
#         0.9014499 ,  0.50994945, -0.35209292,  0.76253396, -0.3267104 ,
#         1.4955629 , -0.61775124, -0.49385917,  0.15207219, -1.0277957 ,
#        -0.49972427,  1.0027637 ,  1.7673011 ,  1.0910833 ,  0.90659   ,
#         0.43077993,  1.442865  , -0.31152156,  0.5090332 ,  1.2310622 ,
#         0.6914662 , -0.343763  ,  0.662846  ,  0.94847727, -0.67104053,
#         0.9089129 , -0.50279486, -0.95999223,  0.919534  , -0.26537117,
#         0.2442427 , -0.81704646,  1.0521867 , -1.2767868 , -0.82207566,
#         0.47108647,  0.7305553 , -0.8179575 ,  0.50547117, -0.12809096,
#         1.0725334 , -0.68749774, -2.2626274 ,  1.1089596 ,  1.4300547 ,
#         0.22042203, -0.35072654,  0.9044687 ,  1.6022012 , -0.8481958 ,
#         0.62367815, -0.552382  ,  0.21529818,  0.30592766,  1.0262758 ,
#        -0.21789443,  1.2283204 ,  0.9035728 , -0.58020014,  0.64116395,
#        -0.85767865, -0.73433006, -1.0516101 , -0.85415566,  0.37140238,
#         0.3862834 , -0.76095253, -0.31143436, -1.3579566 ,  0.00375356,
#        -1.428566  , -1.1208528 , -0.42101792,  0.26044184,  1.7091589 ,
#         0.25292307, -0.5461682 ,  0.6034062 , -0.84199905,  0.08989005,
#         0.13147587, -0.51996875, -3.1252189 ,  1.6088488 ,  0.675383  ],
#       dtype=float32)

# %%
item_vec = [get_mean_vector(model, preprocessed_data[i]) for i in range(len(preprocessed_data))]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """

# %%
len(item_vec)
# Out:
# 750206

# %%
np.save("data/processed_data/item_text_vec.npy", item_vec)

# %% [markdown]
# ## Test Performance

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# testing it against the best shown from word2vec it seems to work better ! some of the weird ones there dont get high scores
# here !!

# %%
sim = cosine_similarity(item_vec[99999].reshape(1,-1), item_vec[569553].reshape(1,-1))
sim
# Out:
# array([[0.22667369]], dtype=float32)

# %% [markdown]
# ## Save array in item data

# %%
df = pd.DataFrame({"text_vec": item_vec})

# %%
df.head()
# Out:
#                                             text_vec
# 0  [0.7984229, 0.09205151, -0.30848747, 0.669923,...
# 1  [0.19540575, -0.07194629, -0.34633487, -0.2459...
# 2  [0.5111147, 0.018874569, 0.22680217, 0.7675127...
# 3  [0.34992826, -0.059115075, -0.25212124, -0.110...
# 4  [0.13192588, -0.19249268, -0.3639368, -0.47083...

# %%
item_text_vec = pd.merge(data_all, df, left_index = True, right_index= True)

# %%
len(item_text_vec)
# Out:
# 750206

# %%
item_text_vec.head()
# Out:
#   anbieter_artikelnummer  anbieterID           erstanlageDatum  stueck_pro_ve  \
# 0          0000400435550      4004.0 2016-03-04 14:39:47+00:00           12.0
# 1    000040053900017-002      4005.0 2018-07-09 12:51:10+00:00            1.0
# 2          0000403433309      4034.0 2018-11-08 13:04:42+00:00           12.0
# 3          0000403434036      4034.0 2016-11-29 15:31:47+00:00           20.0
# 4          00004034LB-03      4034.0 2017-11-15 14:27:01+00:00           10.0
#
#     artikelID anbietermarktplatz                 warengruppe  groupID_1  \
# 0  11608786.0                 DE           Reiseartikel_5199        NaN
# 1  17618200.0                 DE       sonstige Taschen_5202        NaN
# 2  18402615.0                 DE  Kerzen & Kerzenhalter_5107      190.0
# 3  13334081.0                 DE          Lichterketten_5114        NaN
# 4  16079725.0                 DE          Lichterketten_5114      385.0
#
#    groupID_2  preis_euro                                         text_clean  \
# 0        NaN        2.10  Luggage strap with velcro colorful A tear-resi...
# 1        NaN       59.95  Leonardo Verrelli Genuine Leather Bag, Color: ...
#        -8.3976053e-02, -1.0355592e-02, -6.9987059e-01,  1.5655495e-01,
#        -1.0650628e-01,  9.4057582e-02,  3.3676907e-01, -7.1708059e-01,
#         6.7818707e-01,  5.7092077e-01, -1.0606416e+00, -9.0471739e-01,
#        -4.6853509e-02,  3.6385977e-01], dtype=float32),
#        array([-0.5733661 ,  0.03230949, -0.6260626 ,  0.04864204, -0.20536634,
#        -1.1031269 , -0.00419354,  0.49574336,  0.1877817 ,  0.04292899,
#         0.5088362 , -1.0152168 , -0.54251385,  0.39134628, -0.64580846,
#         0.26997352,  0.5812255 ,  0.18334623, -0.26842716,  1.2609795 ,
#        -0.0981971 ,  0.12839867,  0.5508345 ,  0.13242489, -0.7548068 ,
#        -0.5532994 , -0.27994052, -0.13384894, -0.16498938, -0.43955424,
#        -0.75033855,  0.4780059 , -0.22971451, -1.2536834 ,  0.02417334,
#         0.27331156, -0.4866039 ,  0.6167683 , -0.68846697, -0.57827353,
#        -0.5435109 , -0.9146051 ,  0.1028096 ,  0.18189241,  0.2758831 ,
#        -0.20408313, -0.16273522,  0.89115405,  0.6601274 ,  0.5105975 ,
#        -0.4100698 ,  0.60346836,  1.0416981 ,  0.12557313, -0.4249528 ,
#        -0.49905494, -0.60704887, -0.220888  ,  0.09795158,  0.34616432,
#        -0.32422823, -0.36926675,  0.5395709 ,  0.14962861,  0.2805524 ,
#         0.6733948 , -0.25154087,  0.5131558 ,  0.62604374, -0.13621654,
#         0.9122027 ,  0.00421863, -0.21862417,  0.0611558 , -0.33829722,
#         0.93911153, -0.02018392,  0.28753927, -0.2373755 ,  0.33777428,
#         0.05933179,  1.0818095 , -0.43483952,  0.3085372 , -0.38790882,
#         0.71833783,  1.6316471 , -0.15271555,  0.5916814 ,  0.19535209,
#        -0.22486526, -0.2827239 ,  1.1101301 ,  0.42925894,  0.30059302,
#         0.5200564 , -0.08005363,  0.48582852, -0.6713076 ,  1.0492336 ,
#        -0.552513  ,  0.34834567,  0.13085729,  0.00373781,  0.49450713,
#        -0.13324504,  0.3420006 ,  0.66156876, -0.52555275,  0.23139812,
#         0.26640388, -0.3938271 , -0.02025896, -0.30867392,  0.15847799,
#        -0.4306559 , -0.05953157,  0.08662704, -0.04658167,  0.38201007,
#         0.6582977 , -0.23323175, -0.23852217, -0.6123084 , -0.48681873,
#        -0.2460512 , -0.45477766, -0.5887251 ,  0.4607448 , -0.53410906,
#         0.30488884, -0.20643151,  0.22242688,  0.37540597, -0.00192918,
#         0.31212327,  0.558216  ,  0.52734125, -0.76204574,  1.300812  ,
#         0.95102537, -1.0475467 ,  0.6764208 ,  0.16106394, -0.72337806,
#        -0.9484426 ,  0.97549313,  1.1739559 ,  0.5184438 ,  0.08013912],
#       dtype=float32)], dtype=object)

# %%
test = item_text_vec.text_vec[0:10]

# %%
sim = cosine_similarity(item_text_vec.text_vec[99999].reshape(1,-1), test.tolist())
sim
# Out:
# array([[ 0.2663017 ,  0.07443871,  0.0929203 ,  0.2621449 ,  0.36728087,
#          0.35635257,  0.33802235,  0.4352266 ,  0.40028778, -0.11413221]],
#       dtype=float32)
